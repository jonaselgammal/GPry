# %% [markdown]
# # Some didactic plots for the *"How does GPry work"* section

# %% [markdown]
# ## Active learning demo

# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# Input parameters
xmin, xmax = -2, 2
nx = 100
weights, means, stds = [0.7, 0.3], [-1, 1.2], [0.25, 0.35]
# Tmp random choice, to find one that looks good
#x_initial = np.array([np.random.random() for _ in range(2)]) * (xmax - xmin) + xmin
#print(x_initial)
x_initial = [-1.3, 0.65, 1.80]
corr_length_initial = 0.5

# Plot parameters
truth_color = "0.25"
truth_ls = "--"
samples_marker = "o"
samples_color = "k"
gpr_color = "tab:blue"
gpr_alpha = 0.25
acq_color = "tab:orange"
prop_ls = ":"
prop_lw = 2

# %%
# Figure settings

params = {'axes.labelsize': 14,
          'axes.titlesize': 22,
          'font.size': 16,
          'legend.fontsize': 14,
          'font.family': 'serif',
          'font.sans-serif': ['Bitstream Vera Sans'],
          'font.serif': ['Bitstream Vera'],
          'xtick.labelsize': 16,
          'ytick.labelsize': 16,
          'text.usetex': True,
          'text.latex.preamble': r"""\usepackage{amsmath} \usepackage{amssymb} \usepackage{amsfonts}""",
         }
plt.rcParams.update(params)

# %%
# Create truth
xs = np.linspace(xmin, xmax, nx)
if len(means) == 1:
    logpdf = st.norm(means[0], stds[0]).logpdf
else:
    logpdf = lambda x: np.log(sum(weight * st.norm(mean, std).pdf(x) for weight, mean, std in zip(weights, means, stds)))
# Create GP model
kernel = RBF(length_scale=corr_length_initial, length_scale_bounds=(1e-1, 10))
gpr = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=9)
y_initial = logpdf(x_initial)
gpr.fit(np.atleast_2d(x_initial).T, y_initial)
# Create acquisition function
logacq = lambda x, mean, std: 2 * mean + np.log(std)

# Use krigging believer every i%n?
use_kg = False

legend_labels = {}

fig, axes = plt.subplots(nrows=2, ncols=4, sharex=True, sharey="row",
                         gridspec_kw={"height_ratios": [2, 1]}, figsize=(12, 4),
                         layout="constrained"
                        )
for ax in axes[0]:
    legsymbol_truth = ax.plot(xs, logpdf(xs), c=truth_color, ls=truth_ls)
legend_labels[legsymbol_truth[0]] = "True log-pdf"

# Initial GP fit and 0th iteration
i = 0
legsymbol_samples = axes[0][i].scatter(x_initial, y_initial, c=samples_color, marker=samples_marker)
legend_labels[legsymbol_samples] = "Truth evals."
mean_0, std_0 = gpr.predict(np.atleast_2d(xs).T, return_std=True)
legsymbol_mean = axes[0][i].plot(xs, mean_0, c=gpr_color)
legend_labels[legsymbol_mean[0]] = "GPR mean"
legsymbol_bar = axes[0][i].fill_between(xs, mean_0 - 1.96 * std_0, mean_0 + 1.96 * std_0,
                                        alpha=gpr_alpha, color=gpr_color)
legend_labels[legsymbol_bar] = r"GPR $95\%$ c.i."
# Initial acq and next proposal
logacq_0 = logacq(xs, mean_0, std_0)
legsymbol_acq = axes[1][i].plot(xs, logacq_0, c=acq_color)
legend_labels[legsymbol_acq[0]] = "Acquisition func."
x_prop_0 = xs[np.argmax(logacq_0)]
legsymbol_prop = axes[0][i].axvline(x_prop_0, c=acq_color, ls=prop_ls, lw=prop_lw)
legend_labels[legsymbol_prop] = "Proposed next eval."
axes[1][i].axvline(x_prop_0, c=acq_color, ls=prop_ls, lw=prop_lw)

# Add, fit, and next iteration
x_1 = list(x_initial) + [x_prop_0]
if use_kg is not False and not i % use_kg:
    y_1 = gpr.predict(np.atleast_2d(x_1).T)
else:
    y_1 = logpdf(x_1)
gpr.fit(np.atleast_2d(x_1).T, y_1)

# 1st iteration
i = 1
axes[0][i].scatter(x_1, y_1, c=samples_color, marker=samples_marker)
mean_1, std_1 = gpr.predict(np.atleast_2d(xs).T, return_std=True)
axes[0][i].plot(xs, mean_1, c=gpr_color)
axes[0][i].fill_between(xs, mean_1 - 1.96 * std_1, mean_1 + 1.96 * std_1,
                        alpha=gpr_alpha, color=gpr_color)
# Initial acq and next proposal
logacq_1 = logacq(xs, mean_1, std_1)
axes[1][i].plot(xs, logacq_1, c=acq_color)
x_prop_1 = xs[np.argmax(logacq_1)]
axes[0][i].axvline(x_prop_1, c=acq_color, ls=prop_ls, lw=prop_lw)
axes[1][i].axvline(x_prop_1, c=acq_color, ls=prop_ls, lw=prop_lw)

# Add, fit, and next iteration
x_2 = list(x_1) + [x_prop_1]
if use_kg is not False and not i % use_kg:
    y_2 = gpr.predict(np.atleast_2d(x_2).T)
else:
    y_2 = logpdf(x_2)
gpr.fit(np.atleast_2d(x_2).T, y_2)

# 2nd iteration
i = 2
axes[0][i].scatter(x_2, y_2, c=samples_color, marker=samples_marker)
mean_2, std_2 = gpr.predict(np.atleast_2d(xs).T, return_std=True)
axes[0][i].plot(xs, mean_2, c=gpr_color)
axes[0][i].fill_between(xs, mean_2 - 1.96 * std_2, mean_2 + 1.96 * std_2,
                        alpha=gpr_alpha, color=gpr_color)
# Initial acq and next proposal
logacq_2 = logacq(xs, mean_2, std_2)
axes[1][i].plot(xs, logacq_2, c=acq_color)
x_prop_2 = xs[np.argmax(logacq_2)]
axes[0][i].axvline(x_prop_2, c=acq_color, ls=prop_ls, lw=prop_lw)
axes[1][i].axvline(x_prop_2, c=acq_color, ls=prop_ls, lw=prop_lw)

# Add, fit, and next iteration
x_3 = list(x_2) + [x_prop_2]
if use_kg is not False and not i % use_kg:
    y_3 = gpr.predict(np.atleast_2d(x_3).T)
else:
    y_3 = logpdf(x_3)
gpr.fit(np.atleast_2d(x_3).T, y_3)

# 3rd iteration
i = 3
axes[0][i].scatter(x_3, y_3, c=samples_color, marker=samples_marker)
mean_3, std_3 = gpr.predict(np.atleast_2d(xs).T, return_std=True)
axes[0][i].plot(xs, mean_3, c=gpr_color)
axes[0][i].fill_between(xs, mean_3 - 1.96 * std_3, mean_3 + 1.96 * std_3,
                        alpha=gpr_alpha, color=gpr_color)
# Initial acq and next proposal
logacq_3 = logacq(xs, mean_3, std_3)
axes[1][i].plot(xs, logacq_3, c=acq_color)
x_prop_3 = xs[np.argmax(logacq_3)]
axes[0][i].axvline(x_prop_3, c=acq_color, ls=prop_ls, lw=prop_lw)
axes[1][i].axvline(x_prop_3, c=acq_color, ls=prop_ls, lw=prop_lw)

# Adjustments
axes[0][0].set_ylim(-10, 3)
axes[1][0].set_ylim(-20, None)
for ax in axes[1]:
    ax.set_xlabel("x")
axes[0][0].set_ylabel(r"$\log(p)$")
axes[1][0].set_ylabel(r"$\log(a)$")
fig.legend(list(legend_labels), list(legend_labels.values()), ncols=len(legend_labels), loc="upper center", bbox_to_anchor=(0, 1, 1, 0.125))
plt.savefig("images/active_learning.png", dpi=200, bbox_inches="tight")

# %% [markdown]
# ## Kriging-believer demo

# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF

# Input parameters
xmin, xmax = -2, 2
nx = 100
weights, means, stds = [0.7, 0.3], [-1, 1.2], [0.25, 0.35]
# Tmp random choice, to find one that looks good
#x_initial = np.array([np.random.random() for _ in range(2)]) * (xmax - xmin) + xmin
#print(x_initial)
x_initial = [-1.3, 0.65, 1.80]
corr_length_initial = 0.5

# Plot parameters
truth_color = "0.25"
truth_ls = "--"
samples_marker = "o"
samples_color = "k"
kg_marker = "*"
kg_color = "r"
gpr_color = "tab:blue"
gpr_alpha = 0.25
acq_color = "tab:orange"
prop_ls = ":"
prop_lw = 2

# %%
# Figure settings

params = {'axes.labelsize': 14,
          'axes.titlesize': 22,
          'font.size': 16,
          'legend.fontsize': 14,
          'font.family': 'serif',
          'font.sans-serif': ['Bitstream Vera Sans'],
          'font.serif': ['Bitstream Vera'],
          'xtick.labelsize': 16,
          'ytick.labelsize': 16,
          'text.usetex': True,
          'text.latex.preamble': r"""\usepackage{amsmath} \usepackage{amssymb} \usepackage{amsfonts}""",
         }
plt.rcParams.update(params)

# %%
# Create truth
xs = np.linspace(xmin, xmax, nx)
if len(means) == 1:
    logpdf = st.norm(means[0], stds[0]).logpdf
else:
    logpdf = lambda x: np.log(sum(weight * st.norm(mean, std).pdf(x) for weight, mean, std in zip(weights, means, stds)))
# Create GP model
kernel = RBF(length_scale=corr_length_initial, length_scale_bounds=(1e-1, 10))
gpr = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=9)
y_initial = logpdf(x_initial)
gpr.fit(np.atleast_2d(x_initial).T, y_initial)
# Create acquisition function
logacq = lambda x, mean, std: 2 * mean + np.log(std)

# Use krigging believer every i%n?
use_kg = 2

legend_labels = {}

fig, axes = plt.subplots(nrows=2, ncols=5, sharex=True, sharey="row",
                         gridspec_kw={"height_ratios": [2, 1]}, figsize=(12, 4),
                         layout="constrained"
                        )
for ax in axes[0]:
    legsymbol_truth = ax.plot(xs, logpdf(xs), c=truth_color, ls=truth_ls)
legend_labels[legsymbol_truth[0]] = "True log-pdf"

# Initial GP fit and 0th iteration
i = 0
legsymbol_samples = axes[0][i].scatter(x_initial, y_initial, c=samples_color, marker=samples_marker)
legend_labels[legsymbol_samples] = "Truth evals."
mean_0, std_0 = gpr.predict(np.atleast_2d(xs).T, return_std=True)
legsymbol_mean = axes[0][i].plot(xs, mean_0, c=gpr_color)
legend_labels[legsymbol_mean[0]] = "GPR mean"
legsymbol_bar = axes[0][i].fill_between(xs, mean_0 - 1.96 * std_0, mean_0 + 1.96 * std_0,
                                        alpha=gpr_alpha, color=gpr_color)
legend_labels[legsymbol_bar] = r"GPR $95\%$ c.i."
# Initial acq and next proposal
logacq_0 = logacq(xs, mean_0, std_0)
legsymbol_acq = axes[1][i].plot(xs, logacq_0, c=acq_color)
legend_labels[legsymbol_acq[0]] = "Acquisition func."
x_prop_0 = xs[np.argmax(logacq_0)]
legsymbol_prop = axes[0][i].axvline(x_prop_0, c=acq_color, ls=prop_ls, lw=prop_lw)
legend_labels[legsymbol_prop] = "Proposed next eval."
axes[1][i].axvline(x_prop_0, c=acq_color, ls=prop_ls, lw=prop_lw)

# Add, fit, and next iteration
x_1 = list(x_initial) + [x_prop_0]
if use_kg is not False and not i % use_kg:
    y_1 = gpr.predict(np.atleast_2d(x_1).T)
else:
    y_1 = logpdf(x_1)
gpr.fit(np.atleast_2d(x_1).T, y_1)

# 1st iteration
i = 1

if use_kg is not False and i % use_kg:
    axes[0][i].scatter(x_1[:-(use_kg - 1)], y_1[:-(use_kg - 1)], c=samples_color, marker=samples_marker)    
    axes[0][i].scatter(x_1[-(use_kg - 1):], y_1[-(use_kg - 1):], c=kg_color, marker=kg_marker)
else:
    axes[0][i].scatter(x_1, y_1, c=samples_color, marker=samples_marker)    
mean_1, std_1 = gpr.predict(np.atleast_2d(xs).T, return_std=True)
axes[0][i].plot(xs, mean_1, c=gpr_color)
axes[0][i].fill_between(xs, mean_1 - 1.96 * std_1, mean_1 + 1.96 * std_1,
                        alpha=gpr_alpha, color=gpr_color)
# Initial acq and next proposal
logacq_1 = logacq(xs, mean_1, std_1)
axes[1][i].plot(xs, logacq_1, c=acq_color)
x_prop_1 = xs[np.argmax(logacq_1)]
axes[0][i].axvline(x_prop_1, c=acq_color, ls=prop_ls, lw=prop_lw)
axes[1][i].axvline(x_prop_1, c=acq_color, ls=prop_ls, lw=prop_lw)

# Add, fit, and next iteration
x_2 = list(x_1) + [x_prop_1]
if use_kg is not False and not i % use_kg:
    y_2 = gpr.predict(np.atleast_2d(x_2).T)
else:
    y_2 = logpdf(x_2)
gpr.fit(np.atleast_2d(x_2).T, y_2)

# 2nd iteration
i = 2

if use_kg is not False and i % use_kg:
    axes[0][i].scatter(x_2[:-(use_kg - 1)], y_2[:-(use_kg - 1)], c=samples_color, marker=samples_marker)
    axes[0][i].scatter(x_2[-(use_kg - 1):], y_2[-(use_kg - 1):], c=kg_color, marker=kg_marker)
else:
    axes[0][i].scatter(x_2, y_2, c=samples_color, marker=samples_marker)
mean_2, std_2 = gpr.predict(np.atleast_2d(xs).T, return_std=True)
axes[0][i].plot(xs, mean_2, c=gpr_color)
axes[0][i].fill_between(xs, mean_2 - 1.96 * std_2, mean_2 + 1.96 * std_2,
                        alpha=gpr_alpha, color=gpr_color)
# Initial acq and next proposal
logacq_2 = logacq(xs, mean_2, std_2)
axes[1][i].plot(xs, logacq_2, c=acq_color)
x_prop_2 = xs[np.argmax(logacq_2)]
axes[0][i].axvline(x_prop_2, c=acq_color, ls=prop_ls, lw=prop_lw)
axes[1][i].axvline(x_prop_2, c=acq_color, ls=prop_ls, lw=prop_lw)

# Add, fit, and next iteration
x_3 = list(x_2) + [x_prop_2]
if use_kg is not False and not i % use_kg:
    y_3 = gpr.predict(np.atleast_2d(x_3).T)
else:
    y_3 = logpdf(x_3)
gpr.fit(np.atleast_2d(x_3).T, y_3)

# 3rd iteration
i = 3
if use_kg is not False and i % use_kg:
    axes[0][i].scatter(x_3[:-(use_kg - 1)], y_3[:-(use_kg - 1)], c=samples_color, marker=samples_marker)
    axes[0][i].scatter(x_3[-(use_kg - 1):], y_3[-(use_kg - 1):], c=kg_color, marker=kg_marker)
else:
    axes[0][i].scatter(x_3, y_3, c=samples_color, marker=samples_marker)
mean_3, std_3 = gpr.predict(np.atleast_2d(xs).T, return_std=True)
axes[0][i].plot(xs, mean_3, c=gpr_color)
axes[0][i].fill_between(xs, mean_3 - 1.96 * std_3, mean_3 + 1.96 * std_3,
                        alpha=gpr_alpha, color=gpr_color)
# Initial acq and next proposal
logacq_3 = logacq(xs, mean_3, std_3)
axes[1][i].plot(xs, logacq_3, c=acq_color)
x_prop_3 = xs[np.argmax(logacq_3)]
axes[0][i].axvline(x_prop_3, c=acq_color, ls=prop_ls, lw=prop_lw)
axes[1][i].axvline(x_prop_3, c=acq_color, ls=prop_ls, lw=prop_lw)

# Add, fit, and next iteration
x_4 = list(x_3) + [x_prop_3]
if use_kg is not False and not i % use_kg:
    y_4 = gpr.predict(np.atleast_2d(x_4).T)
else:
    y_4 = logpdf(x_4)
gpr.fit(np.atleast_2d(x_4).T, y_4)

# 4th iteration
i = 4
if use_kg is not False and i % use_kg:
    axes[0][i].scatter(x_4[:-(use_kg - 1)], y_4[:-(use_kg - 1)], c=samples_color, marker=samples_marker)
    axes[0][i].scatter(x_4[-(use_kg - 1):], y_4[-(use_kg - 1):], c=kg_color, marker=kg_marker)
else:
    axes[0][i].scatter(x_4, y_4, c=samples_color, marker=samples_marker)
mean_4, std_4 = gpr.predict(np.atleast_2d(xs).T, return_std=True)
axes[0][i].plot(xs, mean_4, c=gpr_color)
axes[0][i].fill_between(xs, mean_4 - 1.96 * std_4, mean_4 + 1.96 * std_4,
                        alpha=gpr_alpha, color=gpr_color)
# Initial acq and next proposal
logacq_4 = logacq(xs, mean_4, std_4)
axes[1][i].plot(xs, logacq_4, c=acq_color)
x_prop_4 = xs[np.argmax(logacq_4)]
axes[0][i].axvline(x_prop_4, c=acq_color, ls=prop_ls, lw=prop_lw)
axes[1][i].axvline(x_prop_4, c=acq_color, ls=prop_ls, lw=prop_lw)

# Adjustments
axes[0][0].set_ylim(-10, 3)
axes[1][0].set_ylim(-20, None)
for ax in axes[1]:
    ax.set_xlabel("x")
axes[0][0].set_ylabel(r"$\log(p)$")
axes[1][0].set_ylabel(r"$\log(a)$")
fig.legend(list(legend_labels), list(legend_labels.values()), ncols=len(legend_labels), loc="upper center", bbox_to_anchor=(0, 1, 1, 0.125))
plt.savefig("images/active_learning_kb.png", dpi=200, bbox_inches="tight")

# %% [markdown]
# ## NORA demo

# %%
import numpy as np
from scipy.stats import multivariate_normal

mean = [3, 2]
cov = [[0.4, 0.24], [0.24, 1.0]]
rv = multivariate_normal(mean, cov)

def lkl(x, y):
    return np.cos((x + y) / 5)

n_initial = 6
bounds = np.array([[-10, 10], [-10, 10]])

seed = int(np.floor(np.random.random() * 100000))

# Fix seed for plot in docs
seed = 36626

print(f"Seed used: {seed}")

n_active_sampling = 3

from gpry.run import Runner
runner = Runner(lkl, bounds, seed=seed, gp_acquisition={"NORA": None}, #{"rank_method": "bulk"}},
                options={"n_initial": n_initial,
                         "max_initial": n_initial,
                         "max_total": n_initial})

# Run. Will stop before performing the 1st NORA iteration
runner.run()

# Run the NORA NS sampling by hand
X_candidates, _, _ = runner.acquisition.multi_add(runner.surrogate, n_active_sampling)
X_mc, y_mc, sigma_y_mc, _ = runner.acquisition.last_mc_sample()
acq_mc = runner.acquisition.acq_func_y_sigma(y_mc, sigma_y_mc)

# %%
import matplotlib.pyplot as plt
from copy import deepcopy

Nmesh = 200
x = np.linspace(bounds[0][0], bounds[0][1], Nmesh)
y = np.linspace(bounds[1][0], bounds[1][1], Nmesh)
X, Y = np.meshgrid(x, y)
xy = np.stack((X, Y), axis=-1).reshape(-1, 2)

train_scatter_kwargs = {"c": "1", "s": 15, "edgecolors": "k"}
candidates_scatter_kwargs = {"c": "r", "s": 15, "edgecolors": "r"}
mc_scatter_kwargs = {"s": 5}
max_scatter_kwargs = {"marker": "x", "s": 50, "facecolor": "k"}
mc_max_scatter_kwargs = {"facecolor": "none", "edgecolor": "red"}
label_iter_candidate = "Per-iteration candidate"

fig, axs = plt.subplots(nrows=1 + n_active_sampling, ncols=3, sharex=True, sharey=True, figsize=(9, 6),
                        subplot_kw={"xlabel": r"$x_1$", "ylabel": r"$x_2$"})
loglikes = lkl(xy[:, 0], xy[:, 1])
axs[0, 0].set_title("True posterior")
axs[0, 0].pcolor(X, Y, loglikes.reshape((Nmesh, Nmesh)) + runner.logprior(runner.surrogate.X[0]))
axs[0, 0].scatter(runner.surrogate.X[:, 0], runner.surrogate.X[:, 1], **train_scatter_kwargs)
axs[0, 1].set_title("Current surrogate posterior")
axs[0, 1].pcolor(X, Y, runner.logp(xy).reshape((Nmesh, Nmesh)))
axs[0, 1].scatter(runner.surrogate.X[:, 0], runner.surrogate.X[:, 1], label="Training samples", **train_scatter_kwargs)
axs[0, 1].scatter(X_candidates[:, 0], X_candidates[:, 1], label="Candidates", **candidates_scatter_kwargs)
axs[0, 2].set_title("NS sample from current surrogate")
axs[0, 2].scatter(X_mc[:, 0], X_mc[:, 1], c=y_mc, **mc_scatter_kwargs)

for i in range(n_active_sampling):
    # Remove leftmost axes and add text
    axs[1 + i, 0].axis("off")
    axs[1 + i, 0].text(-2, -1.25, rf"Ranking iteration \#{i + 1}", size=12)
    
    # Prepare (augmented) surrogate model, without refitting hyperparams
    if i == 0:
        aug_surrogate = runner.surrogate
    else:
        aug_surrogate = deepcopy(runner.surrogate)
        aug_surrogate.append(X_candidates[:i], runner.surrogate.logp(X_candidates[:i]), fit_gpr=False, fit_classifier=False)
    # Acquisition function
    acq_map = runner.acquisition.acq_func_y_sigma(aug_surrogate.logp(xy), aug_surrogate.predict_std(xy))
    i_acq_max = np.argmax(acq_map)
    if i == 0:
        axs[1 + i, 1].set_title("Acquisition function")
    axs[1 + i, 1].set_ylabel(axs[1 + i, 1].get_ylabel())  # doesn't work: no ylabel
    axs[1 + i, 1].pcolor(X, Y, acq_map.reshape((Nmesh, Nmesh)))
    axs[1 + i, 1].scatter(runner.surrogate.X[:, 0], runner.surrogate.X[:, 1], **train_scatter_kwargs)
    axs[1 + i, 1].scatter(X_candidates[i, 0], X_candidates[i, 1], label=label_iter_candidate, **mc_max_scatter_kwargs, zorder=100)
    axs[1 + i, 1].scatter(xy[i_acq_max][0], xy[i_acq_max][1], label="Per-iteration max of acq. func.", **max_scatter_kwargs)
    
    # MC sample from NORA
    if i == 0:
        acq_mc_plot = acq_mc
    else:
        acq_mc_plot = runner.acquisition.acq_func_y_sigma(aug_surrogate.logp(X_mc), aug_surrogate.predict_std(X_mc))
    if i == 0:
        axs[1 + i, 2].set_title("Acquisition function at NS samples")
    i_acq_max_mc = np.argmax(acq_mc_plot)
    axs[1 + i, 2].scatter(X_mc[:, 0], X_mc[:, 1], c=acq_mc_plot, **mc_scatter_kwargs)
    axs[1 + i, 2].scatter(X_mc[i_acq_max_mc][0], X_mc[i_acq_max_mc][1],
                          label=label_iter_candidate, **mc_max_scatter_kwargs)

handles_labels = [ax.get_legend_handles_labels() for ax in fig.axes]
handles, labels = [sum(_, []) for _ in zip(*handles_labels)]
handles_unique, labels_unique = [], []
for h, l in zip(handles, labels):
    if l not in labels_unique:
        handles_unique.append(h)
        labels_unique.append(l)
fig.legend(handles_unique, labels_unique, loc="lower center", ncols=4)
plt.subplots_adjust(hspace=0.4)
plt.savefig("images/active_learning_nora.png", dpi=200, bbox_inches="tight")
